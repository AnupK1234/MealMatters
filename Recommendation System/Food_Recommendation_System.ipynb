# %% [markdown]
# ## Food Recommendation System (MealMatters)
#
# **Introduction**
#
# This is a Machine Learning Food Recommendation System Based on Calories using the combination of Nearest Neighbours (NN) and Naive Bayes (NB) algorithms
#
# We have used the Pandas library for data processing and scikit-learn for implementing the Nearest Neighbors and Naive Bayes algorithms.
# We used food dataset from food.com (recipies.csv). [Link](https://huggingface.co/datasets/AkashPS11/recipes_data_food.com)
#
# The recommendation system combines the strengths of Nearest Neighbors (finding similar recipes based on food contents) and Naive Bayes (suggesting low-calorie alternatives) to provide food recommendations for overweight and obese individuals based on their dietary preferences. It leverages the dataset's information to make informed suggestions for healthier food choices while considering the users' specific nutritional needs.
#
# **How it works**
#
# A user provides a barcode, the recommendation system uses the Nearest Neighbors algorithm to find the recipe in the dataset that has the closest nutritional content to the provided food. The similarity between recipes is determined based on the feature values.
#
# Once the nearest recipe is identified, the recommendation system uses Naive Bayes to suggest a similar recipe with fewer calories. It predicts the target variable (calories) using the provided barcode data and looks for a recipe with a calorie content of less than 400.
#
# Let's start with the implementation:

# %% [markdown]
# **Data Collection:**
#
# We will load data from the dataset into the pandas dataframe. This dataset contains information about various recipes, including their nutritional contents and calorie values

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors, KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, r2_score, mean_squared_error
import os


# Load the dataset
df = pd.read_csv("recipes.csv", low_memory=False)

df.head()
# Out:
#    RecipeId Barcode                               Name  AuthorId  \
# 0      38.0    *38*  Low-Fat Berry Blue Frozen Dessert    1533.0
# 1      39.0    *39*                            Biryani    1567.0
# 2      40.0    *40*                      Best Lemonade    1566.0
# 3      41.0    *41*     Carina's Tofu-Vegetable Kebabs    1586.0
# 4      42.0    *42*                       Cabbage Soup    1538.0
#
#        AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 0          Dancer    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1        elly9812    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2  Stephen Little     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3         Cyclopz    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4       Duckie067    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  ... SaturatedFatContent  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...  ...                 1.3
# 1  Make and share this Biryani recipe from Food.com.  ...                16.6
# 2  This is from one of my  first Good House Keepi...  ...                 0.0
# 3  This dish is best prepared a day in advance to...  ...                 3.8
# 4  Make and share this Cabbage Soup recipe from F...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent FiberContent  \
# 0                8.0          29.8                37.1          3.6
# 1              372.8         368.4                84.4          9.0
# 2                0.0           1.8                81.5          0.4
# 3                0.0        1558.6                64.2         17.3
# 4                0.0         959.3                25.1          4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 29 columns]

# %% [markdown]
# **Data Cleaning:**
#
# After loading the dataset, we perform data cleaning to handle missing values or incorrect data. In this case, we remove rows with missing values

# %%
# Confirm Columns
df.columns
# Out:
# Index(['RecipeId', 'Barcode', 'Name', 'AuthorId', 'AuthorName', 'CookTime',
#        'PrepTime', 'TotalTime', 'DatePublished', 'Description', 'Images',
#        'RecipeCategory', 'Keywords', 'RecipeIngredientQuantities',
#        'RecipeIngredientParts', 'AggregatedRating', 'ReviewCount', 'Calories',
#        'FatContent', 'SaturatedFatContent', 'CholesterolContent',
#        'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent',
#        'ProteinContent', 'RecipeServings', 'RecipeYield',
#        'RecipeInstructions'],
#       dtype='object')

# %%
# Select necessary columns
df = df[['RecipeId', 'Barcode', 'Name', 'CookTime', 'PrepTime', 'TotalTime', 'Calories',
       'FatContent', 'SaturatedFatContent', 'CholesterolContent',
       'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent',
       'ProteinContent', 'RecipeServings', 'DatePublished', 'RecipeInstructions', 'Images']]

df
# Out:
#          RecipeId Barcode                               Name CookTime  \
# 0            38.0    *38*  Low-Fat Berry Blue Frozen Dessert    PT24H
# 1            39.0    *39*                            Biryani    PT25M
# 2            40.0    *40*                      Best Lemonade     PT5M
# 3            41.0    *41*     Carina's Tofu-Vegetable Kebabs    PT20M
# 4            42.0    *42*                       Cabbage Soup    PT30M
# ...           ...     ...                                ...      ...
# 1048538       NaN      ()                                NaN      NaN
# 1048539       NaN      ()                                NaN      NaN
# 1048540       NaN      ()                                NaN      NaN
# 1048541       NaN      ()                                NaN      NaN
# 1048542       NaN      ()                                NaN      NaN
#
#         PrepTime TotalTime  Calories  FatContent  SaturatedFatContent  \
# 0          PT45M  PT24H45M     170.9         2.5                  1.3
# 1           PT4H   PT4H25M    1110.7        58.8                 16.6
# 2          PT30M     PT35M     311.1         0.2                  0.0
# 3          PT24H  PT24H20M     536.1        24.0                  3.8
# 4          PT20M     PT50M     103.6         0.4                  0.1
# ...          ...       ...       ...         ...                  ...
# 1048538      NaN       NaN       NaN         NaN                  NaN
# 1048539      NaN       NaN       NaN         NaN                  NaN
# 1048540      NaN       NaN       NaN         NaN                  NaN
# 1048541      NaN       NaN       NaN         NaN                  NaN
# 1048542      NaN       NaN       NaN         NaN                  NaN
#
#          CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                       8.0           29.8                 37.1           3.6
# 1                     372.8          368.4                 84.4           9.0
# 2                       0.0            1.8                 81.5           0.4
# 3                       0.0         1558.6                 64.2          17.3
# 4                       0.0          959.3                 25.1           4.8
# ...                     ...            ...                  ...           ...
# 1048538                 NaN            NaN                  NaN           NaN
# 1048539                 NaN            NaN                  NaN           NaN
# 1048540                 NaN            NaN                  NaN           NaN
# 1048541                 NaN            NaN                  NaN           NaN
# 1048542                 NaN            NaN                  NaN           NaN
#
#          SugarContent  ProteinContent  RecipeServings         DatePublished  \
# 0                30.2             3.2             4.0  1999-08-09T21:46:00Z
# 1                20.4            63.4             6.0  1999-08-29T13:12:00Z
# 2                77.2             0.3             4.0  1999-09-05T19:52:00Z
# 3                32.1            29.3             2.0  1999-09-03T14:54:00Z
# 4                17.7             4.3             4.0  1999-09-19T06:19:00Z
# ...               ...             ...             ...                   ...
# 1048538           NaN             NaN             NaN                   NaN
# 1048539           NaN             NaN             NaN                   NaN
# 1048540           NaN             NaN             NaN                   NaN
# 1048541           NaN             NaN             NaN                   NaN
# 1048542           NaN             NaN             NaN                   NaN
#
#                                         RecipeInstructions  \
# 0        c("Toss 2 cups berries with sugar.", "Let stan...
# 1        c("Soak saffron in warm milk for 5 minutes and...
# 2        c("Into a 1 quart Jar with tight fitting lid, ...
# 3        c("Drain the tofu, carefully squeezing out exc...
# 4        c("Mix everything together and bring to a boil...
# ...                                                    ...
# 1048538                                                NaN
# 1048539                                                NaN
# 1048540                                                NaN
# 1048541                                                NaN
# 1048542                                                NaN
#
#                                                     Images
# 0        c("https://img.sndimg.com/food/image/upload/w_...
# 1        c("https://img.sndimg.com/food/image/upload/w_...
# 2        c("https://img.sndimg.com/food/image/upload/w_...
# 3        c("https://img.sndimg.com/food/image/upload/w_...
# 4        "https://img.sndimg.com/food/image/upload/w_55...
# ...                                                    ...
# 1048538                                                NaN
# 1048539                                                NaN
# 1048540                                                NaN
# 1048541                                                NaN
# 1048542                                                NaN
#
# [1048543 rows x 19 columns]

# %%
# Handle fields with null values
df[df.isnull().any(axis=1)]
# Out:
#          RecipeId Barcode                     Name CookTime PrepTime  \
# 8            46.0    *46*  A Jad - Cucumber Pickle      NaN    PT25M
# 9            47.0    *47*     Butter Pecan Cookies     PT9M    PT55M
# 10           48.0    *48*         Boston Cream Pie      NaN  PT2H15M
# 12           50.0    *50*        Biscotti Di Prato    PT50M    PT20M
# 14           52.0    *52*          Cafe Cappuccino      NaN     PT5M
# ...           ...     ...                      ...      ...      ...
# 1048538       NaN      ()                      NaN      NaN      NaN
# 1048539       NaN      ()                      NaN      NaN      NaN
# 1048540       NaN      ()                      NaN      NaN      NaN
# 1048541       NaN      ()                      NaN      NaN      NaN
# 1048542       NaN      ()                      NaN      NaN      NaN
#
#         TotalTime  Calories  FatContent  SaturatedFatContent  \
# 8           PT25M       4.3         0.0                  0.0
# 9          PT1H4M      69.0         5.6                  1.4
# 10        PT2H15M     688.2        36.4                 12.9
# 12        PT1H10M      89.4         2.6                  0.3
# 14           PT5M      62.2         0.1                  0.0
# ...           ...       ...         ...                  ...
# 1048538       NaN       NaN         NaN                  NaN
# 1048539       NaN       NaN         NaN                  NaN
# 1048540       NaN       NaN         NaN                  NaN
# 1048541       NaN       NaN         NaN                  NaN
# 1048542       NaN       NaN         NaN                  NaN
#
#          CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 8                       0.0            0.7                  1.1           0.2
# 9                       6.3           15.0                  4.5           0.6
# 10                    105.9          722.3                 84.0           1.6
# 12                     16.6           23.5                 14.5           0.8
# 14                      1.3           36.6                 12.8           0.0
# ...                     ...            ...                  ...           ...
# 1048538                 NaN            NaN                  NaN           NaN
# 1048539                 NaN            NaN                  NaN           NaN
# 1048540                 NaN            NaN                  NaN           NaN
# 1048541                 NaN            NaN                  NaN           NaN
# 1048542                 NaN            NaN                  NaN           NaN
#
#          SugarContent  ProteinContent  RecipeServings         DatePublished  \
# 8                 0.2             0.1             NaN  1999-08-11T19:48:00Z
# 9                 1.6             0.8             NaN  1999-09-07T09:01:00Z
# 10               46.2             8.8             8.0  1999-08-24T04:35:00Z
# 12                7.3             2.3             NaN  1999-08-31T21:19:00Z
# 14               11.8             2.7            18.0  1999-08-31T21:05:00Z
# ...               ...             ...             ...                   ...
# 1048538           NaN             NaN             NaN                   NaN
# 1048539           NaN             NaN             NaN                   NaN
# 1048540           NaN             NaN             NaN                   NaN
# 1048541           NaN             NaN             NaN                   NaN
# 1048542           NaN             NaN             NaN                   NaN
#
#                                         RecipeInstructions  \
# 8        c("Slice the cucumber in four lengthwise, then...
# 9        c("Preheat oven to 350 degrees.", "Cream butte...
# 10       c("Beat egg whites until soft peaks form.", "G...
# 12       c("EGG WASH 1 Egg, large 1 tsp Water In the bo...
# 14       c("Stir ingredients together.", "Process in a ...
# ...                                                    ...
# 1048538                                                NaN
# 1048539                                                NaN
# 1048540                                                NaN
# 1048541                                                NaN
# 1048542                                                NaN
#
#                                                     Images
# 8                                             character(0)
# 9        c("https://img.sndimg.com/food/image/upload/w_...
# 10                                            character(0)
# 12       "https://img.sndimg.com/food/image/upload/w_55...
# 14       c("https://img.sndimg.com/food/image/upload/w_...
# ...                                                    ...
# 1048538                                                NaN
# 1048539                                                NaN
# 1048540                                                NaN
# 1048541                                                NaN
# 1048542                                                NaN
#
# [1048055 rows x 19 columns]

# %%
# Drop fields with NaN values
df = df.dropna()

df
# Out:
#       RecipeId Barcode                                  Name CookTime  \
# 0         38.0    *38*     Low-Fat Berry Blue Frozen Dessert    PT24H
# 1         39.0    *39*                               Biryani    PT25M
# 2         40.0    *40*                         Best Lemonade     PT5M
# 3         41.0    *41*        Carina's Tofu-Vegetable Kebabs    PT20M
# 4         42.0    *42*                          Cabbage Soup    PT30M
# ...        ...     ...                                   ...      ...
# 1195    2632.0  *2632*  Stir-Fry Beef & Spinach with Noodles    PT30M
# 1196    2633.0  *2633*        Beef, Pepper & Mushroom Kabobs    PT30M
# 1202    2639.0  *2639*                   Sweet Chicken Curry    PT25M
# 1213    2650.0  *2650*                      Beer Can Chicken  PT1H30M
# 1219    2656.0  *2656*                           Tiramisu II    PT35M
#
#      PrepTime TotalTime  Calories  FatContent  SaturatedFatContent  \
# 0       PT45M  PT24H45M     170.9         2.5                  1.3
# 1        PT4H   PT4H25M    1110.7        58.8                 16.6
# 2       PT30M     PT35M     311.1         0.2                  0.0
# 3       PT24H  PT24H20M     536.1        24.0                  3.8
# 4       PT20M     PT50M     103.6         0.4                  0.1
# ...       ...       ...       ...         ...                  ...
# 1195     PT0S     PT30M     299.0         4.2                  0.6
# 1196     PT0S     PT30M     208.8         8.3                  2.2
# 1202    PT10M     PT35M     114.2         8.1                  2.2
# 1213    PT30M      PT2H     771.5        53.2                 15.2
# 1219    PT25M     PT10H     201.3         5.0                  1.7
#
#       CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                    8.0           29.8                 37.1           3.6
# 1                  372.8          368.4                 84.4           9.0
# 2                    0.0            1.8                 81.5           0.4
# 3                    0.0         1558.6                 64.2          17.3
# 4                    0.0          959.3                 25.1           4.8
# ...                  ...            ...                  ...           ...
# 1195                 0.5          599.9                 54.4           4.2
# 1196                68.0          213.9                  6.1           1.5
# 1202                35.5           37.2                  1.0           0.2
# 1213               243.8          358.0                  5.2           0.2
# 1219               149.7          132.6                 33.2           0.8
#
#       SugarContent  ProteinContent  RecipeServings         DatePublished  \
# 0             30.2             3.2             4.0  1999-08-09T21:46:00Z
# 1             20.4            63.4             6.0  1999-08-29T13:12:00Z
# 2             77.2             0.3             4.0  1999-09-05T19:52:00Z
# 3             32.1            29.3             2.0  1999-09-03T14:54:00Z
# 4             17.7             4.3             4.0  1999-09-19T06:19:00Z
# ...            ...             ...             ...                   ...
# 1195           8.0            12.8             4.0  1999-08-13T13:50:00Z
# 1196           3.9            27.6             4.0  1999-08-11T19:51:00Z
# 1202           0.3             9.0            48.0  1999-08-13T13:28:00Z
# 1213           0.6            57.9             8.0  1999-08-23T12:45:00Z
# 1219          23.3             6.9             6.0  1999-08-08T17:24:00Z
#
#                                      RecipeInstructions  \
# 0     c("Toss 2 cups berries with sugar.", "Let stan...
# 1     c("Soak saffron in warm milk for 5 minutes and...
# 2     c("Into a 1 quart Jar with tight fitting lid, ...
# 3     c("Drain the tofu, carefully squeezing out exc...
# 4     c("Mix everything together and bring to a boil...
# ...                                                 ...
# 1195  c("Stack beef steaks; cut lengthwise in half a...
# 1196  c("Trim fat from beef steak; cut into 1 1/4-in...
# 1202  c("In a pot, brown the meat, onions and garlic...
# 1213  c("Place wood chips in bowl.", "Pop tabs of ea...
# 1219  c("Combine egg yolks and water in heavy saucep...
#
#                                                  Images
# 0     c("https://img.sndimg.com/food/image/upload/w_...
# 1     c("https://img.sndimg.com/food/image/upload/w_...
# 2     c("https://img.sndimg.com/food/image/upload/w_...
# 3     c("https://img.sndimg.com/food/image/upload/w_...
# 4     "https://img.sndimg.com/food/image/upload/w_55...
# ...                                                 ...
# 1195                                       character(0)
# 1196  "https://img.sndimg.com/food/image/upload/w_55...
# 1202                                       character(0)
# 1213  c("https://img.sndimg.com/food/image/upload/w_...
# 1219                                       character(0)
#
# [488 rows x 19 columns]

# %%
# @title Calories

from matplotlib import pyplot as plt
df['Calories'].plot(kind='line', figsize=(14, 4), title='Calories')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.dtypes
# Out:
# RecipeId               float64
# Barcode                 object
# Name                    object
# CookTime                object
# PrepTime                object
# TotalTime               object
# Calories               float64
# FatContent             float64
# SaturatedFatContent    float64
# CholesterolContent     float64
# SodiumContent          float64
# CarbohydrateContent    float64
# FiberContent           float64
# SugarContent           float64
# ProteinContent         float64
# RecipeServings         float64
# DatePublished           object
# RecipeInstructions      object
# Images                  object
# dtype: object

# %%
# Convert cook, prep, and total time to numeric values in minutes
df['CookTime'] = df['CookTime'].str.extract('(\d+)').astype(float) * 60
df['PrepTime'] = df['PrepTime'].str.extract('(\d+)').astype(float) * 60
df['TotalTime'] = df['TotalTime'].str.extract('(\d+)').astype(float) * 60

# Convert Barcode to digits
df['Barcode'] = df['Barcode'].str.extract('(\d+)').astype(int)
# Convert 'DatePublished' to datetime objects
df['DatePublished'] = pd.to_datetime(df['DatePublished'])
df["Calories"] = df["Calories"].astype(float)
df["FatContent"] = df["FatContent"].astype(float)
df["SaturatedFatContent"] = df["SaturatedFatContent"].astype(float)
df["CholesterolContent"] = df["CholesterolContent"].astype(float)
df["SodiumContent"] = df["SodiumContent"].astype(float)
df["CarbohydrateContent"] = df["CarbohydrateContent"].astype(float)
df["FiberContent"] = df["FiberContent"].astype(float)
df["SugarContent"] = df["SugarContent"].astype(float)
df["ProteinContent"] = df["ProteinContent"].astype(float)
df["RecipeInstructions"] = df["RecipeInstructions"].astype(str)
df["Images"] = df["Images"].astype(str)
# Remove extra quotes from the "Images" and "RecipeInstructions" column
df["RecipeInstructions"] = df["RecipeInstructions"].str.replace('"', '').str.replace("''", "'").str.replace("(", "").str.replace(")", "")
df["Images"] = df["Images"].str.replace('"', '').str.replace("''", "'").str.replace("(", "").str.replace(")", "")
# Out:
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CookTime'] = df['CookTime'].str.extract('(\d+)').astype(float) * 60
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PrepTime'] = df['PrepTime'].str.extract('(\d+)').astype(float) * 60
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalTime'] = df['TotalTime'].str.extract('(\d+)').astype(float) * 60
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Barcode'] = df['Barcode'].str.extract('(\d+)').astype(int)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DatePublished'] = pd.to_datetime(df['DatePublished'])
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Calories"] = df["Calories"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FatContent"] = df["FatContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SaturatedFatContent"] = df["SaturatedFatContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CholesterolContent"] = df["CholesterolContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SodiumContent"] = df["SodiumContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CarbohydrateContent"] = df["CarbohydrateContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FiberContent"] = df["FiberContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SugarContent"] = df["SugarContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ProteinContent"] = df["ProteinContent"].astype(float)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RecipeInstructions"] = df["RecipeInstructions"].astype(str)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Images"] = df["Images"].astype(str)
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RecipeInstructions"] = df["RecipeInstructions"].str.replace('"', '').str.replace("''", "'").str.replace("(", "").str.replace(")", "")
# C:\Users\khism\AppData\Local\Temp\ipykernel_21768\484703665.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Images"] = df["Images"].str.replace('"', '').str.replace("''", "'").str.replace("(", "").str.replace(")", "")

# %%
df.dtypes
# Out:
# RecipeId                           float64
# Barcode                              int32
# Name                                object
# CookTime                           float64
# PrepTime                           float64
# TotalTime                          float64
# Calories                           float64
# FatContent                         float64
# SaturatedFatContent                float64
# CholesterolContent                 float64
# SodiumContent                      float64
# CarbohydrateContent                float64
# FiberContent                       float64
# SugarContent                       float64
# ProteinContent                     float64
# RecipeServings                     float64
# DatePublished          datetime64[ns, UTC]
# RecipeInstructions                  object
# Images                              object
# dtype: object

# %%
df
# Out:
#       RecipeId  Barcode                                  Name  CookTime  \
# 0         38.0       38     Low-Fat Berry Blue Frozen Dessert    1440.0
# 1         39.0       39                               Biryani    1500.0
# 2         40.0       40                         Best Lemonade     300.0
# 3         41.0       41        Carina's Tofu-Vegetable Kebabs    1200.0
# 4         42.0       42                          Cabbage Soup    1800.0
# ...        ...      ...                                   ...       ...
# 1195    2632.0     2632  Stir-Fry Beef & Spinach with Noodles    1800.0
# 1196    2633.0     2633        Beef, Pepper & Mushroom Kabobs    1800.0
# 1202    2639.0     2639                   Sweet Chicken Curry    1500.0
# 1213    2650.0     2650                      Beer Can Chicken      60.0
# 1219    2656.0     2656                           Tiramisu II    2100.0
#
#       PrepTime  TotalTime  Calories  FatContent  SaturatedFatContent  \
# 0       2700.0     1440.0     170.9         2.5                  1.3
# 1        240.0      240.0    1110.7        58.8                 16.6
# 2       1800.0     2100.0     311.1         0.2                  0.0
# 3       1440.0     1440.0     536.1        24.0                  3.8
# 4       1200.0     3000.0     103.6         0.4                  0.1
# ...        ...        ...       ...         ...                  ...
# 1195       0.0     1800.0     299.0         4.2                  0.6
# 1196       0.0     1800.0     208.8         8.3                  2.2
# 1202     600.0     2100.0     114.2         8.1                  2.2
# 1213    1800.0      120.0     771.5        53.2                 15.2
# 1219    1500.0      600.0     201.3         5.0                  1.7
#
#       CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                    8.0           29.8                 37.1           3.6
# 1                  372.8          368.4                 84.4           9.0
# 2                    0.0            1.8                 81.5           0.4
# 3                    0.0         1558.6                 64.2          17.3
# 4                    0.0          959.3                 25.1           4.8
# ...                  ...            ...                  ...           ...
# 1195                 0.5          599.9                 54.4           4.2
# 1196                68.0          213.9                  6.1           1.5
# 1202                35.5           37.2                  1.0           0.2
# 1213               243.8          358.0                  5.2           0.2
# 1219               149.7          132.6                 33.2           0.8
#
#       SugarContent  ProteinContent  RecipeServings             DatePublished  \
# 0             30.2             3.2             4.0 1999-08-09 21:46:00+00:00
# 1             20.4            63.4             6.0 1999-08-29 13:12:00+00:00
# 2             77.2             0.3             4.0 1999-09-05 19:52:00+00:00
# 3             32.1            29.3             2.0 1999-09-03 14:54:00+00:00
# 4             17.7             4.3             4.0 1999-09-19 06:19:00+00:00
# ...            ...             ...             ...                       ...
# 1195           8.0            12.8             4.0 1999-08-13 13:50:00+00:00
# 1196           3.9            27.6             4.0 1999-08-11 19:51:00+00:00
# 1202           0.3             9.0            48.0 1999-08-13 13:28:00+00:00
# 1213           0.6            57.9             8.0 1999-08-23 12:45:00+00:00
# 1219          23.3             6.9             6.0 1999-08-08 17:24:00+00:00
#
#                                      RecipeInstructions  \
# 0     cToss 2 cups berries with sugar., Let stand fo...
# 1     cSoak saffron in warm milk for 5 minutes and p...
# 2     cInto a 1 quart Jar with tight fitting lid, pu...
# 3     cDrain the tofu, carefully squeezing out exces...
# 4     cMix everything together and bring to a boil.,...
# ...                                                 ...
# 1195  cStack beef steaks; cut lengthwise in half and...
# 1196  cTrim fat from beef steak; cut into 1 1/4-inch...
# 1202  cIn a pot, brown the meat, onions and garlic i...
# 1213  cPlace wood chips in bowl., Pop tabs of each b...
# 1219  cCombine egg yolks and water in heavy saucepan...
#
#                                                  Images
# 0     chttps://img.sndimg.com/food/image/upload/w_55...
# 1     chttps://img.sndimg.com/food/image/upload/w_55...
# 2     chttps://img.sndimg.com/food/image/upload/w_55...
# 3     chttps://img.sndimg.com/food/image/upload/w_55...
# 4     https://img.sndimg.com/food/image/upload/w_555...
# ...                                                 ...
# 1195                                         character0
# 1196  https://img.sndimg.com/food/image/upload/w_555...
# 1202                                         character0
# 1213  chttps://img.sndimg.com/food/image/upload/w_55...
# 1219                                         character0
#
# [488 rows x 19 columns]

# %% [markdown]
# **Exploring The Data**
#
# To determine the features to use with the target(Calories), we need to explore how the others relate with the target

# %%
# Exploring how TotalTime relates to Calrories
sns.lmplot(x="TotalTime", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how PrepTime relates to Calrories
sns.lmplot(x="PrepTime", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how CookTime relates to Calrories
sns.lmplot(x="CookTime", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how FatContent relates to Calrories
sns.lmplot(x="FatContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how SaturatedFatContent relates to Calrories
sns.lmplot(x="SaturatedFatContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how CholesterolContent relates to Calrories
sns.lmplot(x="CholesterolContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how SodiumContent relates to Calrories
sns.lmplot(x="SodiumContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how CarbohydrateContent relates to Calrories
sns.lmplot(x="CarbohydrateContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how FiberContent relates to Calrories
sns.lmplot(x="FiberContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how SugarContent relates to Calrories
sns.lmplot(x="SugarContent", y="Calories", data=df, fit_reg=True, ci=None)

# %%
# Exploring how ProteinContent relates to Calrories
sns.lmplot(x="ProteinContent", y="Calories", data=df, fit_reg=True, ci=None)

# %% [markdown]
# **Feature Extraction and Transformation:**
#
# Next, we extract the relevant features for the recommendation system. For the Nearest Neighbors algorithm, we use columns related to food contents ('FatContent', 'SaturatedFatContent', 'CholesterolContent', 'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent') as features. For Naive Bayes, we consider 'Calories' as the target variable.

# %%
# Get user input
age = int(input("Enter your age (in years): "))
weight = float(input("Enter your weight (in kilograms): "))
height = float(input("Enter your height (in centimeters): "))
gender = input("Enter your gender (male/female): ")

# Calculate BMR based on gender
if gender.lower() == "male":
  bmr = 10 * weight + 6.25 * height - 5 * age + 5
elif gender.lower() == "female":
  bmr = 10 * weight + 6.25 * height - 5 * age - 161
else:
  print("Error: Invalid gender. Please enter 'male' or 'female'.")
  bmr = None

# Display BMR
if bmr:
  print("Your Basal Metabolic Rate (BMR) is approximately", round(bmr, 2), "calories per day.")
# Out:
# Your Basal Metabolic Rate (BMR) is approximately 1581.25 calories per day.

# %%
calorie_limit = 400
low_calories_data = df[df['Calories'] < calorie_limit]
low_calories_data
# Out:
#       RecipeId  Barcode                                        Name  CookTime  \
# 0         38.0       38           Low-Fat Berry Blue Frozen Dessert    1440.0
# 2         40.0       40                               Best Lemonade     300.0
# 4         42.0       42                                Cabbage Soup    1800.0
# 7         45.0       45  Buttermilk Pie With Gingersnap Crumb Crust    3000.0
# 13        51.0       51                                    Chai Tea    1500.0
# ...        ...      ...                                         ...       ...
# 1194    2631.0     2631         Stephen's Pork Chop Dinner in a Pan      60.0
# 1195    2632.0     2632        Stir-Fry Beef & Spinach with Noodles    1800.0
# 1196    2633.0     2633              Beef, Pepper & Mushroom Kabobs    1800.0
# 1202    2639.0     2639                         Sweet Chicken Curry    1500.0
# 1219    2656.0     2656                                 Tiramisu II    2100.0
#
#       PrepTime  TotalTime  Calories  FatContent  SaturatedFatContent  \
# 0       2700.0     1440.0     170.9         2.5                  1.3
# 2       1800.0     2100.0     311.1         0.2                  0.0
# 4       1200.0     3000.0     103.6         0.4                  0.1
# 7       1800.0       60.0     228.0         7.1                  1.7
# 13       900.0     2400.0      69.2         3.8                  2.1
# ...        ...        ...       ...         ...                  ...
# 1194     900.0       60.0     291.3         7.1                  2.4
# 1195       0.0     1800.0     299.0         4.2                  0.6
# 1196       0.0     1800.0     208.8         8.3                  2.2
# 1202     600.0     2100.0     114.2         8.1                  2.2
# 1219    1500.0      600.0     201.3         5.0                  1.7
#
#       CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0                    8.0           29.8                 37.1           3.6
# 2                    0.0            1.8                 81.5           0.4
# 4                    0.0          959.3                 25.1           4.8
# 7                   24.5          281.8                 37.5           0.5
# 13                  12.8           53.2                  6.0           0.7
# ...                  ...            ...                  ...           ...
# 1194                52.5          780.5                 36.9           6.8
# 1195                 0.5          599.9                 54.4           4.2
# 1196                68.0          213.9                  6.1           1.5
# 1202                35.5           37.2                  1.0           0.2
# 1219               149.7          132.6                 33.2           0.8
#
#       SugarContent  ProteinContent  RecipeServings             DatePublished  \
# 0             30.2             3.2             4.0 1999-08-09 21:46:00+00:00
# 2             77.2             0.3             4.0 1999-09-05 19:52:00+00:00
# 4             17.7             4.3             4.0 1999-09-19 06:19:00+00:00
# 7             24.7             4.2             8.0 1999-08-06 00:40:00+00:00
# 13             0.0             3.5             4.0 1999-08-16 05:10:00+00:00
# ...            ...             ...             ...                       ...
# 1194           3.4            20.5             4.0 1999-08-15 07:20:00+00:00
# 1195           8.0            12.8             4.0 1999-08-13 13:50:00+00:00
# 1196           3.9            27.6             4.0 1999-08-11 19:51:00+00:00
# 1202           0.3             9.0            48.0 1999-08-13 13:28:00+00:00
# 1219          23.3             6.9             6.0 1999-08-08 17:24:00+00:00
#
#                                      RecipeInstructions  \
# 0     cToss 2 cups berries with sugar., Let stand fo...
# 2     cInto a 1 quart Jar with tight fitting lid, pu...
# 4     cMix everything together and bring to a boil.,...
# 7     cPreheat oven to 350°F., Make pie crust, using...
# 13    cBring water and spices to boil in saucepan., ...
# ...                                                 ...
# 1194  cPeel potatoes and julienne them i.e. cut into...
# 1195  cStack beef steaks; cut lengthwise in half and...
# 1196  cTrim fat from beef steak; cut into 1 1/4-inch...
# 1202  cIn a pot, brown the meat, onions and garlic i...
# 1219  cCombine egg yolks and water in heavy saucepan...
#
#                                                  Images
# 0     chttps://img.sndimg.com/food/image/upload/w_55...
# 2     chttps://img.sndimg.com/food/image/upload/w_55...
# 4     https://img.sndimg.com/food/image/upload/w_555...
# 7     https://img.sndimg.com/food/image/upload/w_555...
# 13                                           character0
# ...                                                 ...
# 1194                                         character0
# 1195                                         character0
# 1196  https://img.sndimg.com/food/image/upload/w_555...
# 1202                                         character0
# 1219                                         character0
#
# [304 rows x 19 columns]

# %%
# Encode the target variable using LabelEncoder
label_encoder = LabelEncoder()
calories_encoded = label_encoder.fit_transform(low_calories_data['Calories'])

# %%
# Feature extraction
features = low_calories_data[['FatContent', 'SaturatedFatContent', 'CholesterolContent',
                 'SodiumContent', 'CarbohydrateContent', 'FiberContent',
                 'SugarContent', 'ProteinContent']]

# Target variable
target = calories_encoded

# %% [markdown]
# **Algorithm Selection and Model Training:**
#
# We will use KNeighborsRegressor from scikit-learn for the Nearest Neighbors algorithm and GaussianNB for Naive Bayes.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Nearest Neighbors model
nn_model = KNeighborsRegressor(n_neighbors=5)
nn_model.fit(X_train, y_train)

# Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(features, target)
# Out:
# GaussianNB()

# %% [markdown]
# **Food Recommendation:**
#
# Let's define a function that takes a barcode, finds the closest recipe based on food contents using the Nearest Neighbors model, and then suggests a similar food with fewer calories using Naive Bayes.

# %%
def food_recommendation(barcode):
    try:
        # Find the nearest neighbors based on food contents
        barcode_data = df[df['Barcode'] == barcode][['FatContent', 'SaturatedFatContent',
                                                        'CholesterolContent', 'SodiumContent',
                                                        'CarbohydrateContent', 'FiberContent',
                                                        'SugarContent', 'ProteinContent']]


        k = 10
        nn_recipe_idxs = nn_model.kneighbors(barcode_data, n_neighbors=k, return_distance=False)[0]
        print(nn_recipe_idxs)
        # Get the recommended recipe based on Nearest Neighbors
        # nn_recipes = [df.iloc[nn_recipe_idx]['Calories'] for nn_recipe_idx in nn_recipe_idxs]
        nn_recipes = [df.iloc[nn_recipe_idx] for nn_recipe_idx in nn_recipe_idxs]
        # Filter out recommendations with calories higher than 400
        nn_recipes = [recipe for recipe in nn_recipes if recipe['Calories'] < calorie_limit][0]['Name']

        # Use Naive Bayes to find a similar recipe with fewer calories
        # calorie_limit = 400
        similar_food_idx = nb_model.predict(barcode_data)[0]
        print(similar_food_idx)
        similar_food = df[df['Calories'] < calorie_limit].iloc[similar_food_idx]['Name']
    except:
        nn_recipes = 'Food Data Not Found'
        similar_food = 'Food Data Not Found'

    return nn_recipes , similar_food

# %% [markdown]
# **Testing:**
#
# We then test out the recommendation system

# %%
# Test
# Example of food recommendation using barcode '38'
nn_recipes, similar_food = food_recommendation(38)
print(f"Nearest Neighbors Recommended Recipes: {nn_recipes}")
print(f"Naive Bayes Recommended Recipe (with fewer calories): {similar_food}")
# Out:
# [125 178 153  74 193 204 115 242  58 130]
# 94
# Nearest Neighbors Recommended Recipes: Curried Vegetables
# Naive Bayes Recommended Recipe (with fewer calories): Zesty Sweet Potato Pie

# %% [markdown]
# **Performance Evaluation:**
#
# To evaluate the models' performance, we'll calculate the R-squared score for the Nearest Neighbors algorithm and use accuracy, precision, recall, and F1-score for the Naive Bayes algorithm.

# %%
# Evaluation

# Nearest Neighbors evaluation : R2 score and MSE are used to calc the accuracy of regression model
nn_r2_score = r2_score(y_test, nn_model.predict(X_test))
# Predictions on the test set using the KNN model
nn_pred = nn_model.predict(X_test)

# Calculate Mean Squared Error (MSE)
nn_mse = mean_squared_error(y_test, nn_pred)

print("KNN Mean Squared Error (MSE):", nn_mse)


# Naive Bayes evaluation
nb_pred = nb_model.predict(X_test)
nb_accuracy = accuracy_score(y_test, nb_pred)
nb_precision = precision_score(y_test, nb_pred, average='weighted')
nb_recall = recall_score(y_test, nb_pred, average='weighted')
nb_f1_score = f1_score(y_test, nb_pred, average='weighted')

print(f"Nearest Neighbors R-squared Score: {nn_r2_score:.2f}")
print(f"Naive Bayes Accuracy: {nb_accuracy:.2f}")
print(f"Naive Bayes Precision: {nb_precision:.2f}")
print(f"Naive Bayes Recall: {nb_recall:.2f}")
print(f"Naive Bayes F1 Score: {nb_f1_score:.2f}")
# Out:
# KNN Mean Squared Error (MSE): 2856.370491803278
# Nearest Neighbors R-squared Score: 0.58
# Naive Bayes Accuracy: 1.00
# Naive Bayes Precision: 1.00
# Naive Bayes Recall: 1.00
# Naive Bayes F1 Score: 1.00

# %% [markdown]
# **Visualization:**
#
# To add some visualizations, we create a correlation matrix and a history plot.

# %%
# Visualization
import seaborn as sns
# Correlation matrix
correlation_matrix = features.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# History plot
plt.figure(figsize=(12, 6))
plt.plot(df['DatePublished'], df['Calories'], marker='o')
plt.xlabel('Date Published')
plt.ylabel('Calories')
plt.title('Calories Over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
